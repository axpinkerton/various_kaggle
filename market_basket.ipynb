# %%
import pandas as pd
import numpy as np
import pmdarima as pmd
import matplotlib.pyplot as plt
import re
from collections import Counter
import math
import itertools
import datetime
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
## had to change the encoding to read the csv
df=pd.read_csv('/Users/APinkerton/Downloads/OnlineRetail.csv',encoding='latin1')

## changing column titles to lower case, just because I prefer them
df.columns=df.columns.str.lower()

## stripping the product descriptions of whitespace on either side
df['description'] = df['description'].str.strip()

## dropping the NaN invoices that won't be helpful for this analysis of market baskets & looking at 
## what was bought together
df.dropna(axis=0, subset=['invoiceno'], inplace=True)

## changing the Integer to strings, as the Invoice shouldn't be treated as a number
df['invoiceno'] = df['invoiceno'].astype('str')

## Invoices with 'C' are credit, so for the time being we can filter them out--a separate analsys
## for JUST these transactions may be useful in the future
df = df[~df['invoiceno'].str.contains('C')]

# %%
## Grouping customer baskets by the invoice number and product description & aggregating the sales units 
## by product description, filling the NaN with 0's & setting the transaction ID as the index of the DataFrame
baskets = (df.groupby(['invoiceno', 'description'])['quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('invoiceno'))
baskets
# Out:
# description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# invoiceno
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
# ...                            ...                      ...
# 581586                         0.0                      0.0
# 581587                         0.0                      0.0
# A563185                        0.0                      0.0
# A563186                        0.0                      0.0
# A563187                        0.0                      0.0
#
# description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# invoiceno
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
# ...                             ...                         ...
# 581586                          0.0                         0.0
# 581587                          0.0                         0.0
# A563185                         0.0                         0.0
# A563186                         0.0                         0.0
# A563187                         0.0                         0.0
#
# description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# invoiceno
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# ...                                ...                        ...
# 581586                             0.0                        0.0
# 581587                             0.0                        0.0
# A563185                            0.0                        0.0
# A563186                            0.0                        0.0
# A563187                            0.0                        0.0
#
# description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# invoiceno
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
# ...                                   ...                               ...
# 581586                                0.0                               0.0
# 581587                                0.0                               0.0
# A563185                               0.0                               0.0
# A563186                               0.0                               0.0
# A563187                               0.0                               0.0
#
# description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# invoiceno
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
# ...                                      ...                            ...
# 581586                                   0.0                            0.0
# 581587                                   0.0                            0.0
# A563185                                  0.0                            0.0
# A563186                                  0.0                            0.0
# A563187                                  0.0                            0.0
#
# description  ...  wrongly coded 20713  wrongly coded 23343  \
# invoiceno    ...
# 536365       ...                  0.0                  0.0
# 536366       ...                  0.0                  0.0
# 536367       ...                  0.0                  0.0
# 536368       ...                  0.0                  0.0
# 536369       ...                  0.0                  0.0
# ...          ...                  ...                  ...
# 581586       ...                  0.0                  0.0
# 581587       ...                  0.0                  0.0
# A563185      ...                  0.0                  0.0
# A563186      ...                  0.0                  0.0
# A563187      ...                  0.0                  0.0
#
# description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# invoiceno
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
# ...                          ...             ...                   ...
# 581586                       0.0             0.0                   0.0
# 581587                       0.0             0.0                   0.0
# A563185                      0.0             0.0                   0.0
# A563186                      0.0             0.0                   0.0
# A563187                      0.0             0.0                   0.0
#
# description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# invoiceno
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
# ...                                  ...                           ...
# 581586                               0.0                           0.0
# 581587                               0.0                           0.0
# A563185                              0.0                           0.0
# A563186                              0.0                           0.0
# A563187                              0.0                           0.0
#
# description  wrongly sold (22719) barcode  wrongly sold as sets  \
# invoiceno
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
# ...                                   ...                   ...
# 581586                                0.0                   0.0
# 581587                                0.0                   0.0
# A563185                               0.0                   0.0
# A563186                               0.0                   0.0
# A563187                               0.0                   0.0
#
# description  wrongly sold sets
# invoiceno
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
# ...                        ...
# 581586                     0.0
# 581587                     0.0
# A563185                    0.0
# A563186                    0.0
# A563187                    0.0
#
# [20610 rows x 4195 columns]

# %%
## Creating a function--if a product's units are 1 or more, it counts as a sale, if it it 0 or a return,
## it doesn't count as a sale
def bool_unit(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
## Mapping the boolean unit to all of the products in the dataframe
item_sets = baskets.applymap(bool_unit)

## Dropping charges for shipping from the dataframe
item_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
## Setting parameters for the apriori function, with a Min Support of 2.5% because there are so many products,
## and using the column names, which correspond to the product title
frequent_itemsets = apriori(item_sets, min_support=0.025, use_colnames=True)

## Inspecting 
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.046337                           (6 RIBBONS RUSTIC CHARM)
# 1    0.029985                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.040175                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.029840                   (72 SWEETHEART FAIRY CAKE CASES)
# 4    0.047550                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 201  0.026783  (PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAI...
# 202  0.029064  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 203  0.025473  (ROSES REGENCY TEACUP AND SAUCER, REGENCY CAKE...
# 204  0.026152  (WOODEN FRAME ANTIQUE WHITE, WOODEN PICTURE FR...
# 205  0.026298  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
#
# [206 rows x 2 columns]

# %%
## Creating a rule for the association rules--Using lift as the metric and a minimum threshold of 1
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

## Filtering the rules dataframe to items with association lift greater than 500% and with a confidence of >50%
## Which yields 61 product association rules
rules[(rules['lift']>5)&(rules['conviction']>.5)]
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                          (ALARM CLOCK BAKELIKE RED)
# 2                       (RED RETROSPOT CHARLOTTE BAG)
# 3                       (CHARLOTTE BAG PINK POLKADOT)
# 4                                (SPACEBOY LUNCH BOX)
# 5                              (DOLLY GIRL LUNCH BOX)
# 6                 (GARDENERS KNEELING PAD CUP OF TEA)
# 7                  (GARDENERS KNEELING PAD KEEP CALM)
# 8                   (GREEN REGENCY TEACUP AND SAUCER)
# 9                    (PINK REGENCY TEACUP AND SAUCER)
# 10                  (GREEN REGENCY TEACUP AND SAUCER)
# 11                  (ROSES REGENCY TEACUP AND SAUCER)
# 12                          (JUMBO BAG RED RETROSPOT)
# 13                   (JUMBO  BAG BAROQUE BLACK WHITE)
# 14                                 (JUMBO BAG APPLES)
# 15                          (JUMBO BAG RED RETROSPOT)
# 16                          (JUMBO BAG RED RETROSPOT)
# 17                          (JUMBO BAG PINK POLKADOT)
# 18                          (JUMBO BAG RED RETROSPOT)
# 19                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 20                          (JUMBO BAG RED RETROSPOT)
# 21                             (JUMBO BAG STRAWBERRY)
# 22                          (JUMBO BAG RED RETROSPOT)
# 23                       (JUMBO BAG WOODLAND ANIMALS)
# 24                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 25                          (JUMBO BAG RED RETROSPOT)
# 26                           (JUMBO STORAGE BAG SUKI)
# 27                          (JUMBO BAG RED RETROSPOT)
# 30                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 31                           (JUMBO STORAGE BAG SUKI)
# 32                          (LUNCH BAG  BLACK SKULL.)
# 33                              (LUNCH BAG CARS BLUE)
# 34                          (LUNCH BAG  BLACK SKULL.)
# 35                          (LUNCH BAG PINK POLKADOT)
# 36                          (LUNCH BAG  BLACK SKULL.)
# 37                          (LUNCH BAG RED RETROSPOT)
# 38                              (LUNCH BAG CARS BLUE)
# 39                          (LUNCH BAG RED RETROSPOT)
# 40                          (LUNCH BAG PINK POLKADOT)
# 41                          (LUNCH BAG RED RETROSPOT)
# 42                        (LUNCH BAG SPACEBOY DESIGN)
# 43                          (LUNCH BAG RED RETROSPOT)
# 44                            (LUNCH BAG SUKI DESIGN)
# 45                          (LUNCH BAG RED RETROSPOT)
# 46                               (LUNCH BAG WOODLAND)
# 47                          (LUNCH BAG RED RETROSPOT)
# 48                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 49                   (PAPER CHAIN KIT 50'S CHRISTMAS)
# 50                  (ROSES REGENCY TEACUP AND SAUCER)
# 51                   (PINK REGENCY TEACUP AND SAUCER)
# 52                  (ROSES REGENCY TEACUP AND SAUCER)
# 53                         (REGENCY CAKESTAND 3 TIER)
# 54                       (WOODEN FRAME ANTIQUE WHITE)
# 55                (WOODEN PICTURE FRAME WHITE FINISH)
# 56  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 57  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 58  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 59                  (GREEN REGENCY TEACUP AND SAUCER)
# 60                  (ROSES REGENCY TEACUP AND SAUCER)
# 61                   (PINK REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                          (ALARM CLOCK BAKELIKE RED)            0.047550
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.050995
# 2                       (CHARLOTTE BAG PINK POLKADOT)            0.050170
# 3                       (RED RETROSPOT CHARLOTTE BAG)            0.036050
# 4                              (DOLLY GIRL LUNCH BOX)            0.043668
# 5                                (SPACEBOY LUNCH BOX)            0.041242
# 6                  (GARDENERS KNEELING PAD KEEP CALM)            0.036778
# 7                 (GARDENERS KNEELING PAD CUP OF TEA)            0.044299
# 8                    (PINK REGENCY TEACUP AND SAUCER)            0.049248
# 9                   (GREEN REGENCY TEACUP AND SAUCER)            0.037166
# 10                  (ROSES REGENCY TEACUP AND SAUCER)            0.049248
# 11                  (GREEN REGENCY TEACUP AND SAUCER)            0.051722
# 12                   (JUMBO  BAG BAROQUE BLACK WHITE)            0.101504
# 13                          (JUMBO BAG RED RETROSPOT)            0.045269
# 14                          (JUMBO BAG RED RETROSPOT)            0.047453
# 15                                 (JUMBO BAG APPLES)            0.101504
# 16                          (JUMBO BAG PINK POLKADOT)            0.101504
# 17                          (JUMBO BAG RED RETROSPOT)            0.059098
# 18                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.101504
# 19                          (JUMBO BAG RED RETROSPOT)            0.041970
# 20                             (JUMBO BAG STRAWBERRY)            0.101504
# 21                          (JUMBO BAG RED RETROSPOT)            0.040029
# 22                       (JUMBO BAG WOODLAND ANIMALS)            0.101504
# 23                          (JUMBO BAG RED RETROSPOT)            0.041873
# 24                          (JUMBO BAG RED RETROSPOT)            0.057011
# 25                (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.101504
# 26                          (JUMBO BAG RED RETROSPOT)            0.057448
# 27                           (JUMBO STORAGE BAG SUKI)            0.101504
# 30                           (JUMBO STORAGE BAG SUKI)            0.057011
# 31                (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.057448
# 32                              (LUNCH BAG CARS BLUE)            0.061766
# 33                          (LUNCH BAG  BLACK SKULL.)            0.055798
# 34                          (LUNCH BAG PINK POLKADOT)            0.061766
# 35                          (LUNCH BAG  BLACK SKULL.)            0.052887
# 36                          (LUNCH BAG RED RETROSPOT)            0.061766
# 37                          (LUNCH BAG  BLACK SKULL.)            0.075885
# 38                          (LUNCH BAG RED RETROSPOT)            0.055798
# 39                              (LUNCH BAG CARS BLUE)            0.075885
# 40                          (LUNCH BAG RED RETROSPOT)            0.052887
# 41                          (LUNCH BAG PINK POLKADOT)            0.075885
# 42                          (LUNCH BAG RED RETROSPOT)            0.056138
# 43                        (LUNCH BAG SPACEBOY DESIGN)            0.075885
# 44                          (LUNCH BAG RED RETROSPOT)            0.052644
# 45                            (LUNCH BAG SUKI DESIGN)            0.075885
# 46                          (LUNCH BAG RED RETROSPOT)            0.049393
# 47                               (LUNCH BAG WOODLAND)            0.075885
# 48                   (PAPER CHAIN KIT 50'S CHRISTMAS)            0.039787
# 49                (PAPER CHAIN KIT VINTAGE CHRISTMAS)            0.056283
# 50                   (PINK REGENCY TEACUP AND SAUCER)            0.051722
# 51                  (ROSES REGENCY TEACUP AND SAUCER)            0.037166
# 52                         (REGENCY CAKESTAND 3 TIER)            0.051722
# 53                  (ROSES REGENCY TEACUP AND SAUCER)            0.096507
# 54                (WOODEN PICTURE FRAME WHITE FINISH)            0.047113
# 55                       (WOODEN FRAME ANTIQUE WHITE)            0.053372
# 56                   (PINK REGENCY TEACUP AND SAUCER)            0.037263
# 57                  (ROSES REGENCY TEACUP AND SAUCER)            0.030713
# 58                  (GREEN REGENCY TEACUP AND SAUCER)            0.029064
# 59  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.049248
# 60  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.051722
# 61  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.037166
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.050995  0.031053    0.653061  12.806462  0.028628    2.735368
# 1             0.047550  0.031053    0.608944  12.806462  0.028628    2.435585
# 2             0.036050  0.025328    0.504836  14.003582  0.023519    1.946726
# 3             0.050170  0.025328    0.702557  14.003582  0.023519    3.193320
# 4             0.041242  0.026104    0.597778  14.494353  0.024303    2.383652
# 5             0.043668  0.026104    0.632941  14.494353  0.024303    2.605391
# 6             0.044299  0.026492    0.720317  16.260379  0.024863    3.417082
# 7             0.036778  0.026492    0.598028  16.260379  0.024863    2.396244
# 8             0.037166  0.030713    0.623645  16.779804  0.028883    2.558314
# 9             0.049248  0.030713    0.826371  16.779804  0.028883    5.475760
# 10            0.051722  0.037263    0.756650  14.629045  0.034716    3.896768
# 11            0.049248  0.037263    0.720450  14.629045  0.034716    3.401012
# 12            0.045269  0.028384    0.279637   6.177184  0.023789    1.325346
